# %%
import pandas as pd
import numpy as np

# %%
import sqlalchemy

from sqlalchemy.sql import text

url = 'postgresql+psycopg2://postgres:$3lfl0v3@localhost:5432/delta_neutral'
engine = sqlalchemy.create_engine(url)

# %%
underlying = 'SPY'
expiration = '2018-06-15'
trade_date = '2018-06-08'

sql = f'''
select *
from otm_history
where underlying = '{underlying}'
and expiration = '{expiration}'
and trade_date = '{trade_date}'
order by strike;
'''

print(sql)
# Out:
# select *
# from otm_history
# where underlying = 'SPY'
# and expiration = '2018-06-15'
# and trade_date = '2018-06-08'
# order by strike;

# %%
with engine.connect() as conn:
    query = conn.execute(text(sql))         
    df_otm = pd.DataFrame(query.fetchall())
df_otm
# Out:
#    underlying  expiration    cp  strike  trade_date     upx   bid   ask
# 0         SPY  2018-06-15   put   265.0  2018-06-08  278.22  0.11  0.12  \
# 1         SPY  2018-06-15   put   265.5  2018-06-08  278.22  0.12  0.13
# 2         SPY  2018-06-15   put   266.0  2018-06-08  278.22  0.13  0.14
# 3         SPY  2018-06-15   put   266.5  2018-06-08  278.22  0.14  0.15
# 4         SPY  2018-06-15   put   267.0  2018-06-08  278.22  0.15  0.16
# 5         SPY  2018-06-15   put   267.5  2018-06-08  278.22  0.16  0.17
# 6         SPY  2018-06-15   put   268.0  2018-06-08  278.22  0.18  0.19
# 7         SPY  2018-06-15   put   268.5  2018-06-08  278.22  0.19  0.20
# 8         SPY  2018-06-15   put   269.0  2018-06-08  278.22  0.21  0.22
# 9         SPY  2018-06-15   put   269.5  2018-06-08  278.22  0.23  0.24
# 10        SPY  2018-06-15   put   270.0  2018-06-08  278.22  0.25  0.26
# 11        SPY  2018-06-15   put   270.5  2018-06-08  278.22  0.27  0.28
# 12        SPY  2018-06-15   put   271.0  2018-06-08  278.22  0.30  0.31
# 13        SPY  2018-06-15   put   271.5  2018-06-08  278.22  0.34  0.35
# 14        SPY  2018-06-15   put   272.0  2018-06-08  278.22  0.37  0.38
# 15        SPY  2018-06-15   put   272.5  2018-06-08  278.22  0.42  0.43
# 16        SPY  2018-06-15   put   273.0  2018-06-08  278.22  0.47  0.48
# 17        SPY  2018-06-15   put   273.5  2018-06-08  278.22  0.53  0.54
# 18        SPY  2018-06-15   put   274.0  2018-06-08  278.22  0.61  0.62
# 19        SPY  2018-06-15   put   274.5  2018-06-08  278.22  0.69  0.70
# 20        SPY  2018-06-15   put   275.0  2018-06-08  278.22  0.79  0.81
# 21        SPY  2018-06-15   put   275.5  2018-06-08  278.22  0.90  0.93
# 22        SPY  2018-06-15   put   276.0  2018-06-08  278.22  1.06  1.07
# 23        SPY  2018-06-15   put   276.5  2018-06-08  278.22  1.21  1.24
# 24        SPY  2018-06-15   put   277.0  2018-06-08  278.22  1.41  1.44
# 25        SPY  2018-06-15   put   277.5  2018-06-08  278.22  1.64  1.67
# 26        SPY  2018-06-15  call   278.0  2018-06-08  278.22  1.46  1.49
# 27        SPY  2018-06-15  call   278.5  2018-06-08  278.22  1.19  1.22
# 28        SPY  2018-06-15  call   279.0  2018-06-08  278.22  0.96  0.98
# 29        SPY  2018-06-15  call   279.5  2018-06-08  278.22  0.76  0.78
# 30        SPY  2018-06-15  call   280.0  2018-06-08  278.22  0.58  0.59
# 31        SPY  2018-06-15  call   280.5  2018-06-08  278.22  0.45  0.46
# 32        SPY  2018-06-15  call   281.0  2018-06-08  278.22  0.33  0.34
# 33        SPY  2018-06-15  call   282.0  2018-06-08  278.22  0.18  0.19
# 34        SPY  2018-06-15  call   282.5  2018-06-08  278.22  0.14  0.15
# 35        SPY  2018-06-15  call   283.0  2018-06-08  278.22  0.10  0.11
# 36        SPY  2018-06-15  call   284.0  2018-06-08  278.22  0.06  0.07
# 37        SPY  2018-06-15  call   285.0  2018-06-08  278.22  0.04  0.05
# 38        SPY  2018-06-15  call   286.0  2018-06-08  278.22  0.03  0.04
# 39        SPY  2018-06-15  call   287.0  2018-06-08  278.22  0.02  0.03
#
#       mid  implied_vol   delta
# 0   0.115       0.1883  0.0385
# 1   0.125       0.1850  0.0421
# 2   0.135       0.1814  0.0458
# 3   0.145       0.1775  0.0496
# 4   0.155       0.1733  0.0536
# 5   0.165       0.1690  0.0579
# 6   0.185       0.1664  0.0646
# 7   0.195       0.1615  0.0693
# 8   0.215       0.1582  0.0767
# 9   0.235       0.1544  0.0843
# 10  0.255       0.1503  0.0924
# 11  0.275       0.1458  0.1009
# 12  0.305       0.1423  0.1121
# 13  0.345       0.1395  0.1260
# 14  0.375       0.1350  0.1387
# 15  0.425       0.1321  0.1560
# 16  0.475       0.1285  0.1742
# 17  0.535       0.1252  0.1954
# 18  0.615       0.1228  0.2210
# 19  0.695       0.1195  0.2478
# 20  0.800       0.1172  0.2796
# 21  0.915       0.1145  0.3139
# 22  1.065       0.1132  0.3532
# 23  1.225       0.1111  0.3944
# 24  1.425       0.1104  0.4391
# 25  1.655       0.1101  0.4851
# 26  1.475       0.1060  0.4671
# 27  1.205       0.1026  0.4168
# 28  0.970       0.0998  0.3655
# 29  0.770       0.0976  0.3148
# 30  0.585       0.0944  0.2632
# 31  0.455       0.0934  0.2189
# 32  0.335       0.0912  0.1752
# 33  0.185       0.0898  0.1095
# 34  0.145       0.0911  0.0886
# 35  0.105       0.0907  0.0676
# 36  0.065       0.0938  0.0435
# 37  0.045       0.0987  0.0302
# 38  0.035       0.1052  0.0229
# 39  0.025       0.1099  0.0163

# %%
df_otm.plot(x='strike', y='implied_vol', kind='scatter')
# Out:
# <Axes: xlabel='strike', ylabel='implied_vol'>

# %%
from bizdays import Calendar
Calendar.load("PMC/NYSE")
# Out:
# Calendar: PMC/NYSE
# Start: 1885-01-01
# End: 2200-12-25
# Weekdays: Saturday, Sunday
# Holidays: 3552
# Financial: True

# %%
df_otm['d2x'] = 5
df_otm['T'] = 5/252
df_otm['american_iv'] = np.nan
df_otm.head()
# Out:
#   underlying  expiration   cp  strike  trade_date     upx   bid   ask    mid
# 0        SPY  2018-06-08  put   262.5  2018-06-01  273.61  0.08  0.09  0.085  \
# 1        SPY  2018-06-08  put   263.0  2018-06-01  273.61  0.09  0.10  0.095
# 2        SPY  2018-06-08  put   264.0  2018-06-01  273.61  0.11  0.12  0.115
# 3        SPY  2018-06-08  put   265.0  2018-06-01  273.61  0.13  0.14  0.135
# 4        SPY  2018-06-08  put   265.5  2018-06-01  273.61  0.14  0.15  0.145
#
#    implied_vol   delta  d2x         T  american_iv
# 0       0.1628  0.0341    5  0.019841          NaN
# 1       0.1599  0.0382    5  0.019841          NaN
# 2       0.1528  0.0468    5  0.019841          NaN
# 3       0.1446  0.0565    5  0.019841          NaN
# 4       0.1400  0.0617    5  0.019841          NaN

# %%
def crr_vanilla(cp, K, T, S0, vol, r, q, american=False, steps=1000):
    dt = T / steps                 # length of time-step
    u = np.exp(vol * np.sqrt(dt))  # up factor
    d = 1.0 / u                    # down factor
    a = np.exp((r-q)*dt)           # growth factor
    p = (a - d) / (u - d)          # risk-neutral up probability
    disc = np.exp(-r*dt)           # discount factor

    # initializing terminal underlying values
    S = S0 * (d**np.arange(steps, -1, -1)) * (u**np.arange(0, steps+1, 1))

    # value of option at final time step
    if cp == 'put':
        V = np.maximum(0, K - S)
    else:
        V = np.maximum(0, S - K)


    # backward recursion through the tree (only to the penultimate step so we can calculate delta)
    for i in np.arange(steps-1,0,-1): 
        S = (S * u)[0:-1] # a tricky way of calculating the previous underlying prices
        V =  disc * (p*V[1:i+2] + (1-p)*V[0:i+1])
        # check for early exercise
        if american:
            if cp == 'put':
                V = np.maximum(V, K - S)
            else:
                V = np.maximum(V, S - K)

    delta = (V[1] - V[0]) / (S[1] - S[0])
    price = disc * (p*V[1] + (1-p)*V[0])
    
    return price, delta

# %%
from scipy.optimize import fsolve
def implied_vol(cp, K, T, S0, px, r, q, american, steps):
    def difference(vol):
        opt_px = crr_vanilla(cp, K, T, S0, vol, r, q, american, steps)[0]
        return opt_px - px
    iv = fsolve(difference, 0.25, xtol=0.001)[0]
    return iv

# %%
for ix_row in range(len(df_otm)):
    cp = df_otm['cp'][ix_row]
    K = df_otm['strike'][ix_row]
    S0 = df_otm['upx'][ix_row]
    px = df_otm['mid'][ix_row]
    T = df_otm['T'][ix_row]
    r = 0
    q = 0
    american = True
    steps = 1000
    df_otm.at[ix_row, 'american_iv'] = implied_vol(cp, K, T, S0, px, r, q, american, steps)

# %%
#df_otm

# %%
df_otm.plot(x='strike', y=['implied_vol','american_iv'])
# Out:
# <Axes: xlabel='strike'>

# %%
-(1 / (5/252)) * np.log((278.22 - 1.245568)/278.22)
# Out:
# 0.22614323525088084
